# %%
import random
import numpy
import tensorflow
import keras

from keras.preprocessing.image import ImageDataGenerator

# %%
main_dir       = "drive/MyDrive/BrainTumorDataSet/BrainTumorDataSet"
data_generator = ImageDataGenerator(validation_split = 0.2)

image_width  = 128
image_height = 128

train_dataset = data_generator.flow_from_directory(main_dir, 
                                                   target_size = (image_width, image_height),
                                                   batch_size = 256,
                                                   class_mode = "binary",
                                                   color_mode = "rgb",
                                                   shuffle = True,
                                                   seed = 57,
                                                   subset = "training")

test_dataset = data_generator.flow_from_directory(main_dir,
                                                  target_size = (image_width, image_height),
                                                  batch_size = 256,
                                                  class_mode = "binary",
                                                  color_mode = "rgb",
                                                  shuffle = True,
                                                  seed = 57,
                                                  subset = "validation")
# Out:
# Found 2223 images belonging to 2 classes.
# Found 554 images belonging to 2 classes.

# %%
model = keras.Sequential()

model.add(keras.layers.Conv2D(32, (3,3), activation = "relu", input_shape = (image_height, image_width, 3)))
model.add(keras.layers.MaxPooling2D(2,2))
model.add(keras.layers.Conv2D(64, (3,3), activation = "relu"))
model.add(keras.layers.MaxPooling2D((2,2)))
model.add(keras.layers.Conv2D(128, (3,3), activation = "relu"))
model.add(keras.layers.MaxPooling2D((2,2)))

model.add(keras.layers.Flatten())
model.add(keras.layers.Dense(512, activation = 'relu'))
model.add(keras.layers.Dropout(rate = 0.3))
model.add(keras.layers.Dense(1, activation = "sigmoid"))

model.summary()
# Out:
# Model: "sequential_7"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d_22 (Conv2D)          (None, 126, 126, 32)      896
#
#  max_pooling2d_21 (MaxPoolin  (None, 63, 63, 32)       0
#  g2D)
#
#  conv2d_23 (Conv2D)          (None, 61, 61, 64)        18496
#
#  max_pooling2d_22 (MaxPoolin  (None, 30, 30, 64)       0
#  g2D)
#
#  conv2d_24 (Conv2D)          (None, 28, 28, 128)       73856
#
#  max_pooling2d_23 (MaxPoolin  (None, 14, 14, 128)      0
#  g2D)
#
#  flatten_6 (Flatten)         (None, 25088)             0
#
#  dense_20 (Dense)            (None, 512)               12845568
#
#  dropout_10 (Dropout)        (None, 512)               0
#
#  dense_21 (Dense)            (None, 1)                 513
#
# =================================================================
# Total params: 12,939,329
# Trainable params: 12,939,329
# Non-trainable params: 0
# _________________________________________________________________

# %%
model.compile(optimizer = "adam", loss = "binary_crossentropy", metrics = ["accuracy"])

history = model.fit(train_dataset, epochs = 10)
# Out:
# Epoch 1/10
# 9/9 [==============================] - 9s 896ms/step - loss: 95.2094 - accuracy: 0.6023
# Epoch 2/10
# 9/9 [==============================] - 8s 908ms/step - loss: 0.6391 - accuracy: 0.7701
# Epoch 3/10
# 9/9 [==============================] - 8s 913ms/step - loss: 0.3826 - accuracy: 0.8426
# Epoch 4/10
# 9/9 [==============================] - 9s 1s/step - loss: 0.3043 - accuracy: 0.8646
# Epoch 5/10
# 9/9 [==============================] - 9s 982ms/step - loss: 0.2207 - accuracy: 0.9087
# Epoch 6/10
# 9/9 [==============================] - 8s 895ms/step - loss: 0.1807 - accuracy: 0.9294
# Epoch 7/10
# 9/9 [==============================] - 8s 885ms/step - loss: 0.1396 - accuracy: 0.9478
# Epoch 8/10
# 9/9 [==============================] - 8s 888ms/step - loss: 0.1015 - accuracy: 0.9627
# Epoch 9/10
# 9/9 [==============================] - 8s 878ms/step - loss: 0.0707 - accuracy: 0.9744
# Epoch 10/10
# 9/9 [==============================] - 8s 902ms/step - loss: 0.0466 - accuracy: 0.9852

# %%
model.save('drive/MyDrive/CancerDetectionModel.h5')
